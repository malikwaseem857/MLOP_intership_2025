# %% [markdown]
# ## MLFlow Projects

# %%
import mlflow
print(mlflow.__version__)
# Out:
# 3.3.2

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("MLOps Project")
# Out:
# 2025/08/30 10:38:06 INFO mlflow.tracking.fluent: Experiment with name 'MLOps Project' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/704691062542939525', creation_time=1756532286983, experiment_id='704691062542939525', last_update_time=1756532286983, lifecycle_stage='active', name='MLOps Project', tags={}>

# %%
with mlflow.start_run():
    mlflow.log_metric('Waseem', 1)
    mlflow.log_metric('Akram',2)
# Out:
# 🏃 View run luminous-snail-831 at: http://127.0.0.1:5000/#/experiments/704691062542939525/runs/99ae1f5e51634399ba7b5d0cf362a454
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/704691062542939525

# %%
with mlflow.start_run():
    mlflow.log_metric('Waseem', 2)
    mlflow.log_metric('Akram',1)
# Out:
# 🏃 View run masked-skunk-149 at: http://127.0.0.1:5000/#/experiments/704691062542939525/runs/389c17c75e354516800aea23dfd54bd4
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/704691062542939525
