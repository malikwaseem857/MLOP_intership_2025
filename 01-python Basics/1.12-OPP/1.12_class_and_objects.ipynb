# %% [markdown]
# ## Classes and Objects in Python
# - classes
# - Objects
# - Instance Variables
# - Methods
# - Constructors

# %%
## Class------> Blue prints

# class WordNetLemmatizer 

class Car :
    pass

car = Car()

# %%
dir(car)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
## window attribute has been created at the bottom
car.windows = 4
dir(car)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'windows']

# %%
tata= Car()
tata.doors= 4

print(tata.doors)
print(tata.windows)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 tata= Car()
#       2 tata.doors= 4
#       4 print(tata.doors)
#
# TypeError: Car.__init__() missing 3 required positional arguments: 'egnine_type', 'windows', and 'company'

# %%
## good practice for class generating 
## self, egnine_type, windows, company are attributes

class Car:
    ## constructor
    def __init__(self, egnine_type, windows, company):
        self.egnine_type = egnine_type
        self.windows = windows
        self.company = company


    def start(self):
        print (f"The {self.engine_type} started!")

# %%
class Car:
    ## constructor
    def __init__(self, egnine_type, windows, company):
        self.egnine_type = egnine_type
        self.windows = windows
        self.company = company


    def start(self):
        print (f"The {self.engine_type} started!")

# %%
## use of constructors class the things in a class

car1 = Car('Petrol_engine', 4, 'Toyota')

print(car1.engine_type)
print(car1.windows)
print(car1.company)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 ## use of constructors class the things in a class
# ----> 3 car1 = Car('Petrol_engine', 4, 'Toyota')
#       5 print(car1.engine_type)
#       6 print(car1.windows)
#
# TypeError: Car() takes no arguments

# %%
car1 = Car('Petrol_engine', 4, 'Toyota')

print(car1.engine_type)
print(car1.windows)
print(car1.company)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 car1 = Car('Petrol_engine', 4, 'Toyota')
#       3 print(car1.engine_type)
#       4 print(car1.windows)
#
# NameError: name 'Car' is not defined

# %%
dir(car)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'windows']

# %%
car2 = Car('Electric Engine', 2, 'Tesla')
car2.start()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 car2 = Car('Electric Engine', 2, 'Tesla')
#       2 car2.start()
#
# NameError: name 'Car' is not defined

# %%
class BankAccount:
    def __init__(self, owner, balance):
        self.ower = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
    
    def check_balance(self, amount):
        return self.balance
    
    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient balance")
        else:
            print(f'The amount of {amount} is withdrawn')
            self.balance -= amount
            print(f'Current balance is {self.balance}')

# %%
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited: {amount}")
            print(f"New Balance: {self.balance}")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds.")
        elif amount <= 0:
            print("Withdrawal amount must be positive.")
        else:
            self.balance -= amount
            print(f"Withdrew: {amount}")
            print(f"Remaining Balance: {self.balance}")

# %%
# Now using the class
acc1 = BankAccount('Waseem', 5000)

print(acc1.owner)         # Output: Waseem
acc1.withdraw(3000)       # Withdraws 3000
acc1.deposit(10000)       # Deposits 10000
# Out:
# Waseem
# Withdrew: 3000
# Remaining Balance: 2000
# Deposited: 10000
# New Balance: 12000

# %%
acc2 = BankAccount('Haseeb', 10000)
acc2.deposit(30000)
acc2.withdraw(20000)
# Out:
# Deposited: 30000
# New Balance: 40000
# Withdrew: 20000
# Remaining Balance: 20000
