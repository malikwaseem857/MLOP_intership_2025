# %% [markdown]
# ## Magic Methods- Dunder Methods

# %%
## Methods with __(doubele underscore)
## Methods with __ (single underscore) are private methods in Python

## They can change the build in function in functionalites of an object

# %%
class Person:
    pass


p1 = Person()

dir(p1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
class Person:
    pass


p1 = Person()

print(p1)

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"{self.name} is {self.age} years old."


p1 = Person('Waseem', 27)

print(p1)
# Out:
# Waseem is 27 years old.
