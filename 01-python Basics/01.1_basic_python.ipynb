# %% [markdown]
# ## Day-1 Python Programming

# %%
## Syntax, Semantics
## Single line, Multiple Comments
## Case Sensitivity
## Indentation
## Line Continuation
## Multiple Statements in one line
# Out:
# 2

# %%
print("Waseem is a beginner in Data scientist")
# Out:
# Waseem is a beginner in Data scientist

# %% [markdown]
# ## Syntax & Sematics

# %% [markdown]
# # Syntax is basic rule to write a code like words, letters or symbols.
# # Syntax is the set of rules that defines the structure of a programming language.
# # Sematics: It is the meaning of the code or what code supposed to do.

# %%
## Single line Comment
print("Waseem is doing practice")  # This is a single line comment

# %%
## Multiple comments
## for python files--

# %%
## Case Sensitivity
name = "Waseem"
Name = "Akram"

# %%
print(name)
print(Name)
# Out:
# Waseem
# Akram

# %%
## Indentation 4-spaces/ one tab
# All the hereichery based on indentation


age=23

if age>21:

    print("You are an adult")
# Out:
# You are an adult

# %%
if age<25:
    print("You are under age.")
# Out:
# You are under age.

# %%
## Line Continuation by Backslash (\)

total = 1+2+67+21+50+41+\
34+50
print(total)
# Out:
# 266

# %%
## Multiple Statements in one line
x = 3;y=21;z=45
# print(x)
# print(y)
# print(z)

print(x);print(y);print(z)
# Out:
# 3
# 21
# 45
